# %%
def saludo():
    print("Hola Mundo")
    
saludo()
# Out:
# Hola mundo

# %% [markdown]
# Challenge 1 🤺 - 10m
# Crear una función que imprima la variable palabra.

# %%
def imprimir_palabra():
    palabra = 'hola'
    print(palabra)

imprimir_palabra()
# Out:
# hola

# %% [markdown]
# Challenge 2 🤺 - 20 min
# Crear una función que reciba dos letras (parámetros) y que verifique si son iguales:
#
# Si son iguales, imprimir "Las letras son iguales".
#
# De lo contrario, imprimir "Las letras son diferentes".

# %%
def comparar_letras(letra1,letra2):
    if letra1==letra2:
        print("Las letras son iguales")
    else:
        print("Las letras son diferentes")
    
comparar_letras('a', 'a')
# Out:
# Las letras son iguales

# %% [markdown]
# Challenge 3 🤺 - 20m
#
# Crear una función que reciba dos parámetros (una palabra y un número), y que retorne `True` si el número es igual a la cantidad de letras de la palabra. En caso contrario, que retorne `False`.
#
# Pista: `cantidad de letras de una palabra en python`

# %%
def comparador_longitud(palabra, numero):
    contador_letras= len(palabra)
    if contador_letras== numero:
        return True
    else:
        return False
    
palabra_ingresada= input('Ingrese una palabra:')
numero_ingresado= int(input('Ingrese un numero:'))

comparador_longitud(palabra_ingresada, numero_ingresado)
# Out:
# True

# %% [markdown]
# Challenge 5 🤺 - 25m
# Pedir al usuario que ingrese 1 palabra, luego convertir esa palabra a una lista con sus caracteres con list(). Agregar esa lista de caracteres a una lista llamada palabras_ingresadas. Repetir el proceso 3 veces. Cada vez que se agregue una lista de caracteres, imprimir la lista palabras_ingresadas.
#
#
# Ejemplo del resultado esperado:
#
# [['c', 'i', 'e', 'l', 'o']]
# Al ingresar la primera palabra
#
# [['c', 'i', 'e', 'l', 'o'], ['c', 'a', 'l', 'o', 'r']]
# Al ingresar la segunda palabra
#
# [['c', 'i', 'e', 'l', 'o'], ['c', 'a', 'l', 'o', 'r'], ['n', 'u', 'b', 'e', 's']]
# Al ingresar la tercera palabra

# %%
lista_total=[]

for i in range(3):
    palabra_ingresar= input("Ingrese una palabra:")
    lista_palabras= list(palabra_ingresar)
    lista_total.append(lista_palabras)
    print(lista_total)
# Out:
# [['c', 'o', 'm', 'o']]
# [['c', 'o', 'm', 'o'], ['e', 's', 't', 'a', 's']]
# [['c', 'o', 'm', 'o'], ['e', 's', 't', 'a', 's'], ['h', 'o', 'y']]

# %% [markdown]
# Challenge 6 🤺 - 25m
#
# Dada la lista de ejemplo:
#
# lista = [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]
#
# Crear una función que imprima una grilla (lista de listas), una línea por cada lista dentro de la lista principal.
#
# Ejemplo del resultado esperado:
#
# ```
# ['h', 'o', 'l', 'i', 's']
# ['h', 'e', 'l', 'l', 'o']
# ['h', 'a', 'l', 'l', 'o']
# ```

# %%
def salto_de_linea(lista):
    for elemento in lista:
        print(elemento)
        
lista_de_ejemplo = [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]

salto_de_linea(lista_de_ejemplo)
# Out:
# ['h', 'o', 'l', 'i', 's']
# ['h', 'e', 'l', 'l', 'o']
# ['h', 'a', 'l', 'l', 'o']
