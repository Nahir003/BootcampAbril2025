# %% [markdown]
# Escribir una funcion que nos pregunte las caracteriticas de un elemento a comprar e imprima el elemento con sus caracteristicas.

# %%
def caracteristicas_de_un_auto(marca, modelo, color, precio):
    print("Características del auto:")
    print("Modelo:", marca)
    print("Marca:", modelo)
    print("Color:", color)       
    print("Precio:", precio)
    print("")
    
marca= input("Ingrese la marca del auto: ")
modelo= input("Ingrese el modelo del auto: ")
color= input("Ingrese el color del auto: ")
precio= int(input("Ingrese el precio del auto: "))

caracteristicas_de_un_auto(marca, modelo, color, precio)

# %%
def preparar_pizza(ingrediente):
    print("Guia para preparar una pizza")
    print("Ingredientes: masa de pizza, salsa de tomate, queso,", ingrediente)
    print("Paso 1: Preparar la masa de pizza")
    print("Paso 2: Agregar salsa de tomate")
    print("Paso 3: Agregar queso")
    print("Paso 4: Agregar", ingrediente) 
    print("Paso 5: Hornear la pizza")
    print("Paso 6: Cortar la pizza")
    print("Paso 7: Servir la pizza")
    print("¡Pizza lista para comer!")
    print(" ")

preparar_pizza("pepperoni")
preparar_pizza("champiñones")
preparar_pizza("aceitunas")

# %% [markdown]
# Crear una función de un proceso que se les ocurra que tenga varios pasos.
# Ejecutar la función 3 veces.

# %%
def prender_fuego():
    print("¡Bienvenido a la guía de encendido de fuego!")
    print("Para encender un fuego, sigue estos pasos:")
    print("Paso 1: Reúne leña seca. ")
    print("Paso 2: Coloca la leña en forma de pirámide.")
    print("Paso 3: Enciende un fósforo y agrega papel o corteza para ayudar a encender.")
    print("Paso 4: Sopla para avivar las llamas.")
    print("Paso 5: Disfruta del fuego y mantén la seguridad.")
    print(" ")
   

prender_fuego()
prender_fuego()
prender_fuego()

# %% [markdown]
# Solicitar al usuario ingresar dos números y almacenarlos en dos variables. Luego, imprimir la suma de los dos números.

# %%
numero1 = int(input("Ingrese un numero"))
numero2 = int(input("Ingrese otro numero"))

#suma
suma= numero1 + numero2

print("La suma de ambos numeros es", suma)

# %% [markdown]
# Asignar el nombre y el apellido de tu compañera/o a las variables nombre y apellido. Luego, imprimir una frase, utilizando las variables.
# EJEMPLO: "Hola. Me llamo Claudia Melgarejo. Mucho gusto."

# %%
nombre = "Luis"
apellido = "Orna"

print("Hola. Me llamo", nombre, apellido + ".", "Mucho gusto.")

# %% [markdown]
# Suma: asignar dos números en dos variables diferentes cantidad_de_manzanas y cantidad_de_naranjas. Luego sumar ambas variables en cantidad_de_frutas. Imprimir la última variable.
#
# Resta: asignar un valor numérico a la variable frutas_vendidas. Luego, asignar la resta entre cantidad_de_frutas y frutas_vendidas a la variable frutas_restantes. Imprimir la última variable.

# %%
cantidad_de_manzana = 34
cantidad_de_naranjas = 23
frutas_vendidas= 21

#Suma
cantidad_de_frutas= cantidad_de_manzana+cantidad_de_naranjas

#Resta
frutas_restantes= cantidad_de_frutas- frutas_vendidas

print("La cantidad de frutas en total es de: ", cantidad_de_frutas)
print("La cantidad de frutas que queda despues de concluida la venta es de:", frutas_restantes)

# %% [markdown]
# Primer codigo. Imprima hola mundo.

# %%
print("Hola mundo")
